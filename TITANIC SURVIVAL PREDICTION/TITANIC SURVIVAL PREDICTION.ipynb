# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data frame

td=pd.read_csv('C:\\Users\\akash\\Desktop\\tested.csv')
td
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
td.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
td.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
td.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
td.corr()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_10860\1050149.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   td.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.023245 -0.026751 -0.034102  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615 -0.000013  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.492143  0.001087  0.018721
# Age            -0.034102 -0.000013 -0.492143  1.000000 -0.091587 -0.061249
# SibSp           0.003818  0.099943  0.001087 -0.091587  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.061249  0.306895  1.000000
# Fare            0.008211  0.191514 -0.577147  0.337932  0.171539  0.230046
#
#                  Fare
# PassengerId  0.008211
# Survived     0.191514
# ...

# %%
td.shape
# Out:
# (418, 12)

# %%
td.size
# Out:
# 5016

# %%
td.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
td.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
td.drop("Cabin",axis=1,inplace=True)
td.head() #Here the Cabin is already dropped, so if you run again,
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked
# 0   330911   7.8292        Q
# 1   363272   7.0000        S
# 2   240276   9.6875        Q
# 3   315154   8.6625        S
# 4  3101298  12.2875        S

# %%
td.dropna(inplace=True)

# %%
sns.heatmap(td.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
td.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 409         1301         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
td.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
td.head(9)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
# ...

# %%
# There are a lot of string values - so replace them with dummy variables
pd.get_dummies(td['Sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         0     1
# 3         0     1
# 4         1     0
# ..      ...   ...
# 409       1     0
# 411       1     0
# 412       1     0
# 414       1     0
# 415       0     1
#
# [331 rows x 2 columns]

# %%
#We don't need two columns for male and female. One is enough
sex = pd.get_dummies(td['Sex'],drop_first=True)
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     1
# 3     1
# 4     0

# %%
embark = pd.get_dummies(td['Embarked'])
embark.head()
# Out:
#    C  Q  S
# 0  0  1  0
# 1  0  0  1
# 2  0  1  0
# 3  0  0  1
# 4  0  0  1

# %%
#Here also, we don't need three columns
embark=pd.get_dummies(td['Embarked'],drop_first=True)
embark.head()
# Out:
#    Q  S
# 0  1  0
# 1  0  1
# 2  1  0
# 3  0  1
# 4  0  1

# %%
#Do the same to the Passenger Class
Pc1 = pd.get_dummies(td['Pclass'],drop_first=True)
Pc1.head()
# Out:
#    2  3
# 0  0  1
# 1  0  1
# 2  1  0
# 3  0  1
# 4  0  1

# %%
td = pd.concat([td,sex,embark,Pc1],axis=1)

# %%
td.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Embarked  male  Q  S  2  3
# 0   330911   7.8292        Q     1  1  0  0  1
# 1   363272   7.0000        S     0  0  1  0  1
# 2   240276   9.6875        Q     1  1  0  1  0
# 3   315154   8.6625        S     1  0  1  0  1
# 4  3101298  12.2875        S     0  0  1  0  1

# %%
td.drop(["Sex","Embarked","PassengerId","Name","Ticket"],axis=1,inplace=True)

# %%
td.drop("Pclass",axis=1,inplace=True)

# %%
td.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0         0  34.5      0      0   7.8292     1  1  0  0  1
# 1         1  47.0      1      0   7.0000     0  0  1  0  1
# 2         0  62.0      0      0   9.6875     1  1  0  1  0
# 3         0  27.0      0      0   8.6625     1  0  1  0  1
# 4         1  22.0      1      1  12.2875     0  0  1  0  1

# %% [markdown]
# # Splitting data

# %%
#Training and Testing Data
#Train Data
X = td.drop("Survived",axis=1)
X.columns = X.columns.astype(str)  #compulsory (All your column headings should be in string format)
y = td["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        57\n           1       1.00      1.00      1.00        43\n\n    accuracy                           1.00       100\n   macro avg       1.00      1.00      1.00       100\nweighted avg       1.00      1.00      1.00       100\n'

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[57,  0],
#        [ 0, 43]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,predictions)
# Out:
# 1.0

# %%
logmodel.score(X_train,y_train)
logmodel.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(td.isnull(),yticklabels = False,cmap = 'viridis')
# Out:
# <Axes: >

# %%
#Analyze the Siblings column
sns.countplot(x="SibSp",data=td)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
# Plot a histogram to analyze the ages of passengers
td['Age'].plot.hist(bins=20, figsize=(10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Analyze the Fare column
td['Fare'].plot.hist(bins=20, figsize=(10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Analyze which passenger class people survived and which did not
sns.countplot(x="Survived",hue="Age",data=td)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#Analyze which passenger class people survived and which did not
sns.countplot(x="Survived",hue="Fare",data=td)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
print("Number of Passenger in the train dataset : ",len(td.index))
# Out:
# Number of Passenger in the train dataset :  331

# %%
#Analyze how many passengers survived and how many did not of total passengers
sns.countplot(x = "Survived",data = td)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Fare',data=td)
# Out:
# <Axes: xlabel='Fare', ylabel='count'>

# %%
sns.countplot(x=td.Survived)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=td.Age)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=td.Fare)
# Out:
# <Axes: xlabel='Fare', ylabel='count'>

# %%
sns.displot(x="Age",data=td)

# %%
# Create a bar plot of the number of survivors by Age
sns.barplot(x='Age', y='Survived', data=td)
plt.show()

# %%
# Create a scatter plot of age vs fare, color coded by survived
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=td)
plt.show()

# %%
#Plot the fare distribution of passengers by Age
sns.boxplot(x='Age', y='Fare', data=td)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare distribution of passengers by passenger class')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.hist(x = [td[td['Survived']==1]['Age'], td[td['Survived']==0]['Age']],stacked=True, color = ['g','r'],label = ['Survived','Not survived'])
plt.title('Age Histogram with Survival')
plt.xlabel('Age')
plt.ylabel('No of passengers')
plt.legend()

# %%
fig = plt.figure(figsize =(10, 7))
plt.hist(x = [td[td['Survived']==1]['Fare'], td[td['Survived']==0]['Fare']], stacked=True, color = ['g','r'],label = ['Survived','Not survived'])
plt.title('Fare Histogram with Survival')
plt.xlabel('Fare')
plt.ylabel('No of passengers')
plt.legend()
